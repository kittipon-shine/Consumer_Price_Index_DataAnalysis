# %% [markdown]
# # <font color=red> PHASE VISUALIZATION </font>

# %% [markdown]
# # ดัชนีราคาผู้บริโภคทั่วไป (Consumer Price Index)
#
# ### วิเคราะห์ดัชนีราคาผู้บริโภคทั่วไปในกรุงเทพและปริมณฑล ตั้งแต่ปีค.ศ. 2017-2020
#
# แหล่งข้อมูล: https://data.moc.go.th/OpenData/CPIGIndexes

# %% [markdown]
# ## Query Parameters
#
# | Name | Data type | Description | Default |
# | --- | --- | --- | --- |
# | region_id | Integer | รหัสภูมิภาค (0 = กรุงเทพและปริมณฑล, 1 = ภาคกลาง, 2 = ภาคตะวันออกเฉียงเหนือ, 3 = ภาคเหนือ, 4 = ภาคใต้, 5 = ประเทศ) | - |
# | index_id | String | รหัสหมวด / กลุ่มดัชนี | 0000000000000000 |
# | from_year | Integer | ปีที่จัดทำดัชนีเริ่มต้น (ค.ศ.) | - |
# | to_year | Integer | ปีที่จัดทำดัชนีสิ้นสุด (ค.ศ.) | - |
#
# Link API: https://dataapi.moc.go.th/cpig-indexes
#
# Example: https://dataapi.moc.go.th/cpig-indexes?region_id=1&index_id=1000000000000000&from_year=2017&to_year=2020
#
# - ค้นหาข้อมูลใน **ภาคกลาง**
# - รหัสหมวดที่ **1000000000000000**
# - ปีที่จัดทำดัชนีเริ่มต้นที่ปี **2017**
# - ปีที่จัดทำดัชนีสิ้นสุดที่ปี **2020**

# %% [markdown]
# ## Responses
#
# Type: Array
#
# - ผลลัพธ์จะมีการเรียงลำดับโดยปีที่จัดทำดัชนี ตามด้วยเดือนที่จัดทำดัชนี ตามด้วยรหัสภูมิภาค
#
# | Name | Data type | Description |
# | --- | --- | --- |
# | index_id | String | รหัสหมวด / กลุ่มดัชนี |
# | index_description | String | ชื่อหมวด / กลุ่มดัชนี |
# | region_id | Integer | รหัสภูมิภาค |
# | region_name | String | ชื่อภูมิภาค |
# | base_year | 	Integer	 | ปีฐานดัชนี |
# | year | 	Integer	 | ปีที่จัดทำดัชนี |
# | month | 	Integer	 | เดือนที่จัดทำดัชนี |
# | price_index | Float | ดัชนีราคา |
# | mom | Float | อัตราการเปลี่ยนแปลงเทียบกับเดือนก่อนหน้า |
# | yoy | Float | อัตราการเปลี่ยนแปลงเทียบกับเดือนเดียวกันปีก่อนหน้า |
# | aoa | Float | อัตราการเปลี่ยนแปลงเทียบกับช่วงเดียวกันปีก่อนหน้า |
#
# ![NewIMG](data/response_ex.PNG)

# %% [markdown]
# ## รหัสหมวด/กลุ่มดัชนี (Index_id)
# แสดงรหัสหมวด/กลุ่มดัชนี (Index_id) ที่ต้องใส่ในลิงก์ API และใช้ช่วยในการอ่านข้อมูล

# %%
import pandas as pd
import numpy as np
index_id_df = pd.read_csv('data/รหัสหมวดดัชนี CPI_INDEX 31-8-2020.csv', dtype={'รหัสดัชนี': np.int64})
index_id_df
# Out:
#             รหัสดัชนี                            ชื่อหมวด/กลุ่มดัชนี
# 0                   0                                   รวมทุกรายการ
# 1    1000000000000000          หมวดอาหารและเครื่องดื่มไม่มีแอลกอฮอล์
# 2    1100000000000000                               อาหารปรุงที่บ้าน
# 3    1110000000000000                  ข้าว  แป้งและผลิตภัณฑ์จากแป้ง
# 4    1111000000000000                                           ข้าว
# ..                ...                                            ...
# 185  9510000000000000                             น้ำมัน 91 95 ดีเซล
# 186  9520000000000000                   CPI ไม่รวมน้ำมัน 91 95 ดีเซล
# 187  9600000000000000  CPI ไม่รวมน้ำมัน 91 95 ดีเซล และรายการของ คน.
# 188  9700000000000000                              CPI ไม่รวมอาหารสด
# 189  9800000000000000                              CPI ไม่รวมพลังงาน
#
# [190 rows x 2 columns]

# %% [markdown]
# # Staging

# %% [markdown]
# ## ดึงข้อมูลจากลิงก์ API

# %%
#!pip install urllib3 requests
#ให้ลง urllib3 และ requests ก่อนถ้ายังไม่มี
import json, urllib
import pandas as pd

# %% [markdown]
# อ่านข้อมูล**รหัสหมวด/กลุ่มดัชนี (Index_id)** จากไฟล์**รหัสหมวดดัชนี CPI_INDEX 31-8-2020.csv**ที่เก็บไว้ในโฟลเดอร์ data
#
# ข้อมูลที่อ่านมาจะเก็บไว้ในตัวแปร **CPI_Index** แต่ค่าที่ต้องการใช้มีแค่**รหัสหมวด/กลุ่มดัชนี (Index_id)** จึงทำการเลือกเฉพาะคอลัมน์**รหัสดัชนี**แล้วเก็บไว้ในตัวแปร **CPI_index_id**
#
# ข้อมูลที่เก็บไว้ในตัวแปร **CPI_index_id** อยู่ในรูปแบบของ pandas.Series ซึ่งไม่สะดวกต่อการใช้งานจึงทำการเปลี่ยนให้อยู่ในรูปแบบของ list โดยเก็บข้อมูลไว้ในตัวแปร **CPI_index_id_list**

# %%
CPI_Index = pd.read_csv("data/รหัสหมวดดัชนี CPI_INDEX 31-8-2020.csv", dtype={'รหัสดัชนี': np.int64})
CPI_index_id = CPI_Index['รหัสดัชนี']
CPI_index_id_list = CPI_index_id.tolist()
# CPI_index_id_list

# %% [markdown]
# สร้างตัวแปร **data** เพื่อรอเก็บข้อมูลที่อ่านเข้ามา

# %%
data = []

def addData(lists): #รับข้อมูลที่อยู่ในรุปแบบของ list
    for i in range(len(lists)): #อ่านข้อมูลตามความยาวของ list นั้น
        data.append(lists[i]) #เอาข้อมูลใน list แต่ละตัวซึ่งอยู่ในรูปของ dict ไปเก็บไว้ในตัวแปร data

# %% [markdown]
# ในงานนี้จะวิเคราะห์เฉพาะดัชนีราคาผู้บริโภคทั่วไปในกรุงเทพและปริมณฑล ตั้งแต่ปีค.ศ. 2017-2020 เลยทำการสร้างตัวแปรและกำหนดค่า
#
# _ถ้าต้องการดึงข้อมูลในภูมิภาค ปีเริ่มต้นและปีสุดท้ายอื่น ๆ สามารถแก้ไขค่าที่ตัวแปรได้เลย_
# - **region_id** เท่ากับ 0 (กรุงเทพและปริมณฑล)
# - **from_year** เท่ากับ 2017 (เริ่มอ่านข้อมูลตั้งแต่ปีค.ศ. 2017)
# - **to_year** เท่ากับ 2020 (อ่านข้อมูลถึงปีค.ศ. 2020)
#
#
# เนื่องจากข้อมูลที่ต้องการดึงมีหลายหมวดจึงต้องทำการสร้างลิงก์ API แล้วค่อย ๆ ดึงทีละรอบ
#
# โดยเริ่มจากวนลูปในตัวแปร **CPI_index_id_list** ที่เก็บข้อมูลรหัสหมวด/กลุ่มดัชนี (Index_id) โดย i ในแต่ละรอบคือรหัสหมวดที่ต้องใส่ไปในลิงก์ จึงทำการสร้างตัวแปร **url** เพื่อใช้เก็บลิงก์ที่จะขอข้อมูลในแต่ละรอบ จากนั้นก็เอา parameters ต่าง ๆ ใส่เข้าไป
#
# โดยที่ต้องใส่โค้ดส่วนนี้ `str(i) + ('0' * (16 - len(str(i))))` เพราะว่า **index_id** ที่ใช้ใส่ในลิงก์ API ต้องมีทั้งหมด 16 หลักและเลข 0 ต่อท้ายถ้าหากไม่ครบ 16 หลัก (0000000000000000) แต่ข้อมูลใน **CPI_index_id_list** บางตัวมีไม่ถึง 16 หลัก เช่น 0
# - โค้ดในส่วนนี้ `str(i)` จึงทำการแปลงข้อมูลเป็น string เพื่อรวมกับส่วนด้านหลัง
# - โค้ดในส่วนนี้ `('0' * (16 - len(str(i))))` จะทำการนับความยาวของ i ซึ่งคือ index_id ที่วนเข้ามาในแต่ละรอบ จึงทำการแปลงข้อมูล string แล้วค่อยทำการนับความยาวของ i แล้วนำ 16 - ความยาวของ i เพื่อนำไปคูณกับ '0' เพื่อสร้าง 0 ที่เหลือมาต่อท้ายกับโค้ดในส่วนด้านหน้าเพื่อให้ index_id ครบ 16 หลัก
#
# Example รอบที่ 1-3:
# 1. https://dataapi.moc.go.th/cpig-indexes?region_id=0&index_id=0000000000000000&from_year=2017&to_year=2020
# 2. https://dataapi.moc.go.th/cpig-indexes?region_id=0&index_id=1000000000000000&from_year=2017&to_year=2020
# 3. https://dataapi.moc.go.th/cpig-indexes?region_id=0&index_id=1100000000000000&from_year=2017&to_year=2020

# %%
region_id = "0"
from_year="2017"
to_year="2020"

# url = 'https://dataapi.moc.go.th/cpig-indexes?region_id=0&index_id=1000000000000000&from_year=2017&to_year=2020'

for i in CPI_index_id_list:
    url = "https://dataapi.moc.go.th/cpig-indexes?region_id=" + region_id + "&index_id=" + str(i) + ('0' * (16 - len(str(i)) ) ) + "&from_year=" + from_year + "&to_year=" + to_year
    
    response = urllib.request.urlopen(url) #ส่ง request ขอข้อมูล
    raw_json = response.read().decode("utf-8") #อ่านข้อมูลที่รับกลับมา ข้อมูลมีส่วนที่เป็นภาษาไทยเลยต้อง decode ด้วย utf-8
    addData(json.loads(raw_json)) #loads json ที่อ่านค่าได้ซึ่งเมื่ออ่านแล้วจะอยู่ในรูป [{key:value}] ส่งค่าที่อ่านได้ที่อยู่ในรูปของ list ไปที่ function addData() เพื่อเอาข้อมูลมาเก็บไว้
    
print(len(data))
# Out:
# 7748

# %%
df = pd.json_normalize(data) #นำตัวแปร data ที่เก็บข้อมูลทั้งหมดไว้มาแปลงให้อยู่ในรูปของ dataframe
df
# Out:
#               index_id                 index_description  region_id  \
# 0     0000000000000000                      รวมทุกรายการ          0
# 1     0000000000000000                      รวมทุกรายการ          0
# 2     0000000000000000                      รวมทุกรายการ          0
# 3     0000000000000000                      รวมทุกรายการ          0
# 4     0000000000000000                      รวมทุกรายการ          0
# ...                ...                               ...        ...
# 7743  9520000000000000  CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล          0
# 7744  9700000000000000                 CPI ไม่รวมอาหารสด          0
# 7745  9700000000000000                 CPI ไม่รวมอาหารสด          0
# 7746  9800000000000000                 CPI ไม่รวมพลังงาน          0
# 7747  9800000000000000                 CPI ไม่รวมพลังงาน          0
#
#                   region_name  base_year  year  month  price_index   mon  \
# 0     กรุงเทพมหานครและปริมณฑล       2015  2017      1       100.53  0.07
# 1     กรุงเทพมหานครและปริมณฑล       2015  2017      2       100.53  0.00
# 2     กรุงเทพมหานครและปริมณฑล       2015  2017      3       100.18 -0.35
# 3     กรุงเทพมหานครและปริมณฑล       2015  2017      4       100.34  0.16
# 4     กรุงเทพมหานครและปริมณฑล       2015  2017      5       100.48  0.14
# ...                       ...        ...   ...    ...          ...   ...
# 7743  กรุงเทพมหานครและปริมณฑล       2015  2020      8       102.67  0.23
# 7744  กรุงเทพมหานครและปริมณฑล       2015  2019     11       102.45  0.04
# 7745  กรุงเทพมหานครและปริมณฑล       2015  2019     12       102.48  0.03
# 7746  กรุงเทพมหานครและปริมณฑล       2015  2019     11       103.05 -0.13
# 7747  กรุงเทพมหานครและปริมณฑล       2015  2019     12       103.04 -0.01
#
#        yoy   aoa
# 0     1.18  1.18
# 1     1.00  1.09
# 2     0.49  0.88
# 3     0.18  0.71
# 4    -0.04  0.56
# ...    ...   ...
# 7743 -0.21 -0.69
# 7744  0.19  0.39
# 7745  0.67  0.41
# 7746  0.84  1.27
# 7747  0.99  1.25
#
# [7748 rows x 11 columns]

# %% [markdown]
# ## แปลงข้อมูลจาก DataFrame ไปเป็น .csv

# %%
#เก็บข้อมูลในรูปแบบไฟล์ csv โดยเก็บไว้ในชื่อว่า data.csv และต้องตั้งค่า encoding เป็น utf-8-sig เพราะมีข้อมูลที่เป็นภาษาไทย 
df.to_csv('data/data.csv', header=True, index=False, encoding='utf-8-sig')

# %% [markdown]
# # Preparation

# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv')
df
# Out:
#               index_id                 index_description  region_id  \
# 0                    0                      รวมทุกรายการ          0
# 1                    0                      รวมทุกรายการ          0
# 2                    0                      รวมทุกรายการ          0
# 3                    0                      รวมทุกรายการ          0
# 4                    0                      รวมทุกรายการ          0
# ...                ...                               ...        ...
# 7743  9520000000000000  CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล          0
# 7744  9700000000000000                 CPI ไม่รวมอาหารสด          0
# 7745  9700000000000000                 CPI ไม่รวมอาหารสด          0
# 7746  9800000000000000                 CPI ไม่รวมพลังงาน          0
# 7747  9800000000000000                 CPI ไม่รวมพลังงาน          0
#
#                   region_name  base_year  year  month  price_index   mon  \
# 0     กรุงเทพมหานครและปริมณฑล       2015  2017      1       100.53  0.07
# 1     กรุงเทพมหานครและปริมณฑล       2015  2017      2       100.53  0.00
# 2     กรุงเทพมหานครและปริมณฑล       2015  2017      3       100.18 -0.35
# 3     กรุงเทพมหานครและปริมณฑล       2015  2017      4       100.34  0.16
# 4     กรุงเทพมหานครและปริมณฑล       2015  2017      5       100.48  0.14
# ...                       ...        ...   ...    ...          ...   ...
# 7743  กรุงเทพมหานครและปริมณฑล       2015  2020      8       102.67  0.23
# 7744  กรุงเทพมหานครและปริมณฑล       2015  2019     11       102.45  0.04
# 7745  กรุงเทพมหานครและปริมณฑล       2015  2019     12       102.48  0.03
# 7746  กรุงเทพมหานครและปริมณฑล       2015  2019     11       103.05 -0.13
# 7747  กรุงเทพมหานครและปริมณฑล       2015  2019     12       103.04 -0.01
#
#        yoy   aoa
# 0     1.18  1.18
# 1     1.00  1.09
# 2     0.49  0.88
# 3     0.18  0.71
# 4    -0.04  0.56
# ...    ...   ...
# 7743 -0.21 -0.69
# 7744  0.19  0.39
# 7745  0.67  0.41
# 7746  0.84  1.27
# 7747  0.99  1.25
#
# [7748 rows x 11 columns]

# %% [markdown]
# ลองหาค่า missing value แต่ไม่พบ

# %%
df.isna().sum()
# Out:
# index_id             0
# index_description    0
# region_id            0
# region_name          0
# base_year            0
# year                 0
# month                0
# price_index          0
# mon                  0
# yoy                  0
# aoa                  0
# dtype: int64

# %% [markdown]
# ทำการ group แถวที่มี **index_description** เหมือนกันไว้ด้วยกันแล้วทำการนับจำนวนแถว ข้อมูลที่ได้จะอยู่ในรูปของ pandas.Series และเก็บไว้ในตัวแปร **countGroup**
#
# ตัวแปร **countGroup** อ่านค่าลำบาก เลยแปลงให้อยู่ในรูปของ dict เพื่อที่จะได้เห็นชัดเจนว่า **index_description** แต่ละตัวมีจำนวนแถวทั้งหมดเท่าไรและเก็บไว้ในตัวแปร **dictCountGroup**
#
# เอาตัวแปร **dictCountGroup** มาเรียงลำดับจากน้อยไปมากโดยเรียงจาก value ซึ่งคือจำนวนแถวทั้งหมด เพื่อให้ง่ายต่อการวิเคราะห์

# %%
countGroup = df['index_description'].groupby(df['index_description']).count()
dictCountGroup = countGroup.to_dict()
{k: v for k, v in sorted(dictCountGroup.items(), key=lambda item: item[1])}
# Out:
# {'CPI ไม่รวมพลังงาน': 2,
#  'CPI ไม่รวมอาหารสด': 2,
#  'CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล': 44,
#  'กลุ่มอาหารสดและพลังงาน': 44,
#  'กางเกงบุรุษ': 44,
#  'กางเกงสตรีและกระโปรงสตรี': 44,
#  'กางเกงเด็ก': 44,
#  'การบันเทิงและการอ่าน': 44,
#  'การศาสนา': 44,
#  'การศึกษา': 44,
#  'การศึกษาระดับประถมศึกษา': 44,
#  'การศึกษาระดับมัธยมศึกษา ด้านเทคนิคและอาชีวะ': 44,
#  'การศึกษาระดับมัธยมศึกษาสายสามัญ': 44,
#  'การศึกษาระดับอุดมศึกษา': 44,
#  'การสื่อสาร': 44,
#  'ของเล่น': 44,
#  'ข้าว': 44,
#  'ข้าว  แป้งและผลิตภัณฑ์จากแป้ง': 44,
#  'คนรับใช้ / คนงาน': 44,
#  'คนไข้นอก': 44,
#  'คนไข้ใน': 44,
#  'ค่าการบันเทิง': 44,
#  'ค่าของใช้ส่วนบุคคล': 44,
#  'ค่าจ้าง': 44,
#  'ค่าจ้างตัดเย็บและอุปกรณ์': 44,
#  'ค่าซื้อยานพาหนะ': 44,
#  'ค่าซ่อมแซม': 44,
#  'ค่าซ่อมแซมและดูแลรักษา': 44,
#  'ค่าตรวจรักษา ค่าบริการ และค่ายาของคนไข้ใน': 44,
#  'ค่าตรวจรักษาและค่ายา': 44,
#  'ค่าตรวจวินิจฉัยทางห้องปฏิบัติการ': 44,
#  'ค่าตรวจสายตา': 44,
#  'ค่าตรวจโรครักษา ค่าบริการ และค่ายาของคนไข้นอก': 44,
#  'ค่าทำฟัน': 44,
#  'ค่าที่พักอาศัย': 44,
#  'ค่าธรรมเนียมและค่าสมาชิก': 44,
#  'ค่าบริการการสื่อสาร': 44,
#  'ค่าบริการด้านรังสี': 44,
#  'ค่าบริการบำรุงรักษายานยนต์': 44,
#  'ค่าบริการส่วนบุคคล': 44,
#  'ค่าบริการส่วนบุคคลเพื่อความผ่านคลาย': 44,
#  'ค่าบริการส่วนบุคคลเพื่อความสวยงาม': 44,
#  'ค่าบัตรประกันสุขภาพและประกันชีวิต': 44,
#  'ค่าประกันภัยรถ': 44,
#  'ค่าภาษี': 44,
#  'ค่าภาษีและประกันภัยรถยนต์': 44,
#  'ค่ายา': 44,
#  'ค่ายาและเวชภัณฑ์': 44,
#  'ค่ารักษาพยาบาล': 44,
#  'ค่าห้องพักคนไข้': 44,
#  'ค่าอาหาร ของถวายพระ ไหว้เจ้าและอื่น ๆ': 44,
#  'ค่าอุปกรณ์การบันเทิง': 44,
#  'ค่าอุปกรณ์กีฬาและเครื่องเล่น': 44,
#  'ค่าเช่า': 44,
#  'ค่าเรียนพิเศษ': 44,
#  'ค่าเล่าเรียนและค่าธรรมเนียมการศึกษา': 44,
#  'ค่าแรง': 44,
#  'ค่าโดยสารนอกท้องถิ่น': 44,
#  'ค่าโดยสารสาธารณะ': 44,
#  'ค่าโดยสารในท้องถิ่น': 44,
#  'ค่าใช้จ่ายที่เกี่ยวกับรถ': 44,
#  'ค่าใช้จ่ายส่วนบุคคล': 44,
#  'ค่าใช้จ่ายอื่น ๆ เกี่ยวกับการศึกษา': 44,
#  'ค่าใช้จ่ายเกี่ยวกับการทำสวนประดับบ้าน': 44,
#  'ค่าใช้จ่ายเกี่ยวกับการอ่าน': 44,
#  'ค่าใช้จ่ายเกี่ยวกับสัตว์เลี้ยง': 44,
#  'ค่าใช้จ่ายในการเดินทางโอกาสพิเศษและท่องเที่ยว': 44,
#  'ดัชนีราคาผู้บริโภคพื้นฐาน': 44,
#  'ดัชนีราคาผู้บริโภคพื้นฐาน (ไม่รวมค่าเช่าบ้าน)': 44,
#  'นมและผลิตภัณฑ์นม': 44,
#  'น้ำตาลและขนมหวาน': 44,
#  'น้ำประปา': 44,
#  'น้ำมัน 91 , 95 , ดีเซล': 44,
#  'น้ำมันเชื้อเพลิง': 44,
#  'น้ำมันและไขมัน': 44,
#  'บริภัณฑ์อื่น ๆ': 44,
#  'บุรุษ': 44,
#  'ปลาน้ำจืดสด': 44,
#  'ปลาน้ำทะเลสด': 44,
#  'ปลาแปรรูป': 44,
#  'ปลาและสัตว์น้ำ': 44,
#  'ผลิตภัณฑ์จากแป้ง': 44,
#  'ผลิตภัณฑ์น้ำตาล': 44,
#  'ผลิตภัณฑ์ยาสูบ': 44,
#  'ผลิตภัณฑ์รองเท้า': 44,
#  'ผลิตภัณฑ์สุรา': 44,
#  'ผลิตภัณฑ์เบียร์': 44,
#  'ผลิตภัณฑ์ไวน์': 44,
#  'ผลไม้สด': 44,
#  'ผลไม้สดแปรรูปและอื่นๆ': 44,
#  'ผลไม้แปรรูปและอื่น ๆ': 44,
#  'ผักสด': 44,
#  'ผักสดแปรรูปและอื่นๆ': 44,
#  'ผักแปรรูปและอื่นๆ': 44,
#  'ผักและผลไม้': 44,
#  'ผ้าและเสื้อผ้า': 44,
#  'พลังงาน': 44,
#  'ยานพาหนะ': 44,
#  'ยานพาหนะและน้ำมันเชื้อเพลิง': 44,
#  'รวมทุกรายการ': 44,
#  'รองเท้ากีฬาและผ้าใบบุรุษ': 44,
#  'รองเท้ากีฬาและผ้าใบสตรี': 44,
#  'รองเท้ากีฬาและผ้าใบเด็ก': 44,
#  'รองเท้าบุรุษ': 44,
#  'รองเท้าสตรี': 44,
#  'รองเท้าหุ้มส้นบุรุษ': 44,
#  'รองเท้าหุ้มส้นสตรี': 44,
#  'รองเท้าเด็ก': 44,
#  'รองเท้าแตะบุรุษ': 44,
#  'รองเท้าแตะสตรี': 44,
#  'รองเท้าแตะเด็ก': 44,
#  'วัสดุก่อสร้าง': 44,
#  'สตรี': 44,
#  'สัตว์น้ำ': 44,
#  'สัตว์น้ำแปรรูป': 44,
#  'สิ่งทอสำหรับใช้ในบ้าน': 44,
#  'สิ่งที่เกี่ยวกับทำความสะอาด': 44,
#  'หนังสือ': 44,
#  'หนังสือแบบเรียนเอกชน': 44,
#  'หนังสือและอุปกรณ์การศึกษา': 44,
#  'หมวดการตรวจรักษาและบริการส่วนบุคคล': 44,
#  'หมวดการบันเทิงการอ่าน การศึกษา และการศาสนา': 44,
#  'หมวดพาหนะ การขนส่ง และการสื่อสาร': 44,
#  'หมวดยาสูบและเครื่องดื่มมีแอลกอฮอล์': 44,
#  'หมวดอาหารและเครื่องดื่มไม่มีแอลกอฮอล์': 44,
#  'หมวดอื่น ๆ ไม่ใช่อาหาร และเครื่องดื่ม': 44,
#  'หมวดเครื่องนุ่งห่มและรองเท้า': 44,
#  'หมวดเคหสถาน': 44,
#  'อาหารบริโภค-นอกบ้าน': 44,
#  'อาหารบริโภค-ในบ้าน': 44,
#  'อาหารปรุงที่บ้าน': 44,
#  'อาหารสด': 44,
#  'อาหารสำเร็จรูป': 44,
#  'อาหารและเครื่องดื่ม (ไม่รวมอาหารสด)': 44,
#  'อุปกรณ์กีฬา': 44,
#  'อุปกรณ์ซ่อมแซมบ้าน': 44,
#  'อุปกรณ์ยานพาหนะ': 44,
#  'อุปกรณ์เกี่ยวกับการศึกษา': 44,
#  'เครื่องดื่มมีแอลกอฮอลล์': 44,
#  'เครื่องดื่มไม่มีแอลกอฮอล์': 44,
#  'เครื่องถวายพระ': 44,
#  'เครื่องประกอบอาหาร': 44,
#  'เครื่องประดับบุรุษ': 44,
#  'เครื่องปรุงรส': 44,
#  'เครื่องปรุงอาหาร': 44,
#  'เครื่องรับอุปกรณ์สื่อสาร': 44,
#  'เครื่องสุขภัณฑ์': 44,
#  'เครื่องแต่งบ้าน': 44,
#  'เครื่องแต่งบ้านและบริภัณฑ์อื่นๆ': 44,
#  'เครื่องแบบชาย': 44,
#  'เครื่องแบบหญิง': 44,
#  'เครื่องแบบเด็ก': 44,
#  'เครื่องใช้เบ็ดเตล็ดในบ้าน': 44,
#  'เชื้อเพลิงในบ้าน': 44,
#  'เด็ก': 44,
#  'เนื้อสัตว์': 44,
#  'เนื้อสัตว์ เป็ดไก่ และสัตว์น้ำ': 44,
#  'เนื้อสัตว์สด': 44,
#  'เนื้อสัตว์แปรรูป': 44,
#  'เป็ด ไก่': 44,
#  'เป็ด ไก่  สด': 44,
#  'เป็ด ไก่  สำเร็จรูปและแปรรูป': 44,
#  'เวชภัณฑ์': 44,
#  'เสื้อบุรุษ': 44,
#  'เสื้อผ้าบุรุษอื่นๆ': 44,
#  'เสื้อผ้าสตรีอื่นๆ': 44,
#  'เสื้อผ้าเด็กอื่นๆ': 44,
#  'เสื้อสตรี': 44,
#  'เสื้อเด็ก': 44,
#  'แป้งและผลิตภัณฑ์จากแป้ง': 44,
#  'แสงสว่าง': 44,
#  'ไข่': 44,
#  'ไข่และผลิตภัณฑ์นม': 44,
#  'ไฟฟ้า': 44,
#  'ไฟฟ้า  เชื้อเพลิง  น้ำประปาและแสงสว่าง': 44,
#  'ไม่รวมอาหาร เครื่องดื่ม และพลังงาน': 44,
#  'ค่าบริการอื่น ๆ': 88}

# %% [markdown]
# หลังจากทำการรันแล้วจะเห็นได้ว่าหมวดส่วนใหญ่จะมีแถวทั้งหมด 44 แถว โดย 44 แถวมาจากปีค.ศ. 2017-2020 โดยปีค.ศ. 2017-2019 แต่ละปีจะมีทั้งหมด 12 แถว แต่ปีค.ศ. 2020 ยังไม่จบปีเลยมีข้อมูลถึงแค่เดือนสิงหาคมจึงทำให้มีทั้งหมด 8 แถว เมื่อนำมารวมกันแล้ว (12+12+12+8) จึงมีทั้งหมด 44 แถว _(1 แถว = 1 เดือน)_
#
# แต่จะมี 3 หมวดที่แตกต่างจากหมวดอื่น ๆ ได้แก่ **CPI ไม่รวมพลังงาน, CPI ไม่รวมอาหารสด** มีทั้งหมด 2 แถวและ **ค่าบริการอื่น ๆ** มีทั้งหมด 88 แถว

# %% [markdown]
# ลบแถวที่มี index_description เท่ากับ **CPI ไม่รวมพลังงาน**และ **CPI ไม่รวมอาหารสด** เพราะมีข้อมูลน้อยไป เนื่องจากงานนี้จะวิเคราะห์ดัชนีราคาผู้บริโภคทั่วไปในกรุงเทพและปริมณฑล ตั้งแต่ปีค.ศ. 2017-2020 ซึ่งต้องมีข้อมูลทั้งหมดหมวดละ 44 แถว แต่ 2 หมวดดังกล่าวมีข้อมูลไม่พอจึงต้องลบทิ้ง

# %%
df = df[df.index_description != 'CPI ไม่รวมพลังงาน']
df = df[df.index_description != 'CPI ไม่รวมอาหารสด']

# %% [markdown]
# ตรวจสอบแถวที่มี index_description เท่ากับ **ค่าบริการอื่น ๆ** เพราะมีจำนวนแถวที่แตกต่างจากข้อมูลตัวอื่น ๆ

# %%
df[df.index_description == 'ค่าบริการอื่น ๆ']
# Out:
#               index_id index_description  region_id              region_name  \
# 4576  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4577  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4578  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4579  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4580  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# ...                ...               ...        ...                      ...
# 4835  4122400000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4836  4122400000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4837  4122400000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4838  4122400000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4839  4122400000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
#
#       base_year  year  month  price_index  mon   yoy   aoa
# 4576       2015  2017      1       102.08  0.0  1.46  1.46
# 4577       2015  2017      2       102.08  0.0  1.46  1.46
# 4578       2015  2017      3       102.08  0.0  1.46  1.46
# 4579       2015  2017      4       102.08  0.0  1.46  1.46
# 4580       2015  2017      5       102.08  0.0  1.46  1.46
# ...         ...   ...    ...          ...  ...   ...   ...
# 4835       2015  2020      4       103.82  0.0  0.00  0.00
# 4836       2015  2020      5       103.82  0.0  0.00  0.00
# 4837       2015  2020      6       103.82  0.0  0.00  0.00
# 4838       2015  2020      7       103.82  0.0  0.00  0.00
# 4839       2015  2020      8       103.82  0.0  0.00  0.00
#
# [88 rows x 11 columns]

# %% [markdown]
# หลังจากตรวจสอบจะเห็นว่าทั้ง 2 ตัวมีข้อมูล **index_id, price_index** ที่แตกต่างกัน แต่มี **index_description** ที่เหมือนกันเลยทำให้มีจำนวนแถวมากกว่าหมวดอื่น ๆ
#
# จึงทำการแก้ไข้โดยนำ **price_index** ของทั้ง 2 ตัวมาเฉลี่ยกัน แล้วนำค่าเฉลี่ยที่ได้แทนลงไปใน **price_index** ของ **index_id** ที่เท่ากับ `4121500000000000` แล้วทำการลบแถวที่ **index_id** เท่ากับ `4122400000000000`

# %%
df_1 = df[df.index_id == 4121500000000000]
df_2 = df[df.index_id == 4122400000000000]
print('index_id = 4121500000000000\n', 'price_index =', df_1['price_index'].drop_duplicates().iloc[0], 
      '\n\n',
      'index_id = 4122400000000000\n', 'price_index =', df_2['price_index'].drop_duplicates().iloc[0])
# Out:
# index_id = 4121500000000000
#  price_index = 102.08
#
#  index_id = 4122400000000000
#  price_index = 103.82

# %%
#กำหนดให้ priceIndexFirst เก็บค่า price_index ของ index_id ที่เท่ากับ 4121500000000000
priceIndexFirst =  df[df.index_id == 4121500000000000]['price_index'].iloc[0]
priceIndexFirst

#กำหนดให้ priceIndexSecond เก็บค่า price_index ของ index_id ที่เท่ากับ 4122400000000000
priceIndexSecond =  df[df.index_id == 4122400000000000]['price_index'].iloc[0]
priceIndexSecond
# Out:
# 103.82

# %%
newPriceIndex = ((df[df.index_id == 4121500000000000]['price_index'].add(priceIndexSecond, fill_value=0))/2).iloc[0]
print(newPriceIndex)

df[df.index_id == 4121500000000000] = df[df.index_id == 4121500000000000].replace(priceIndexFirst, newPriceIndex)
# Out:
# 102.94999999999999

# %%
df = df[df.index_id != 4122400000000000]
df[df.index_description == 'ค่าบริการอื่น ๆ']
# Out:
#               index_id index_description  region_id              region_name  \
# 4576  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4577  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4578  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4579  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4580  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4581  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4582  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4583  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4584  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4585  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4586  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4587  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4588  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4589  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4590  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4591  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4592  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4593  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4594  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4595  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4596  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4597  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4598  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4599  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4600  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4601  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4602  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4603  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4604  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4605  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4606  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4607  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4608  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4609  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4610  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4611  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4612  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4613  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4614  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4615  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4616  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4617  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4618  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
# 4619  4121500000000000   ค่าบริการอื่น ๆ          0  กรุงเทพมหานครและปริมณฑล
#
#       base_year  year  month  price_index  mon   yoy   aoa
# 4576       2015  2017      1       102.95  0.0  1.46  1.46
# 4577       2015  2017      2       102.95  0.0  1.46  1.46
# 4578       2015  2017      3       102.95  0.0  1.46  1.46
# 4579       2015  2017      4       102.95  0.0  1.46  1.46
# 4580       2015  2017      5       102.95  0.0  1.46  1.46
# 4581       2015  2017      6       102.95  0.0  1.46  1.46
# 4582       2015  2017      7       102.95  0.0  1.46  1.46
# 4583       2015  2017      8       102.95  0.0  1.46  1.46
# 4584       2015  2017      9       102.95  0.0  1.46  1.46
# 4585       2015  2017     10       102.95  0.0  1.46  1.46
# 4586       2015  2017     11       102.95  0.0  0.00  1.33
# 4587       2015  2017     12       102.95  0.0  0.00  1.21
# 4588       2015  2018      1       102.95  0.0  0.00  0.00
# 4589       2015  2018      2       102.95  0.0  0.00  0.00
# 4590       2015  2018      3       102.95  0.0  0.00  0.00
# 4591       2015  2018      4       102.95  0.0  0.00  0.00
# 4592       2015  2018      5       102.95  0.0  0.00  0.00
# 4593       2015  2018      6       102.95  0.0  0.00  0.00
# 4594       2015  2018      7       102.95  0.0  0.00  0.00
# 4595       2015  2018      8       102.95  0.0  0.00  0.00
# 4596       2015  2018      9       102.95  0.0  0.00  0.00
# 4597       2015  2018     10       102.95  0.0  0.00  0.00
# 4598       2015  2018     11       102.95  0.0  0.00  0.00
# 4599       2015  2018     12       102.95  0.0  0.00  0.00
# 4600       2015  2019      1       102.95  0.0  0.00  0.00
# 4601       2015  2019      2       102.95  0.0  0.00  0.00
# 4602       2015  2019      3       102.95  0.0  0.00  0.00
# 4603       2015  2019      4       102.95  0.0  0.00  0.00
# 4604       2015  2019      5       102.95  0.0  0.00  0.00
# 4605       2015  2019      6       102.95  0.0  0.00  0.00
# 4606       2015  2019      7       102.95  0.0  0.00  0.00
# 4607       2015  2019      8       102.95  0.0  0.00  0.00
# 4608       2015  2019      9       102.95  0.0  0.00  0.00
# 4609       2015  2019     10       102.95  0.0  0.00  0.00
# 4610       2015  2019     11       102.95  0.0  0.00  0.00
# 4611       2015  2019     12       102.95  0.0  0.00  0.00
# 4612       2015  2020      1       102.95  0.0  0.00  0.00
# 4613       2015  2020      2       102.95  0.0  0.00  0.00
# 4614       2015  2020      3       102.95  0.0  0.00  0.00
# 4615       2015  2020      4       102.95  0.0  0.00  0.00
# 4616       2015  2020      5       102.95  0.0  0.00  0.00
# 4617       2015  2020      6       102.95  0.0  0.00  0.00
# 4618       2015  2020      7       102.95  0.0  0.00  0.00
# 4619       2015  2020      8       102.95  0.0  0.00  0.00

# %%
countGroup = df['index_description'].groupby(df['index_description']).count()
dictCountGroup = countGroup.to_dict()
{k: v for k, v in sorted(dictCountGroup.items(), key=lambda item: item[1])}.get('ค่าบริการอื่น ๆ')
# Out:
# 44

# %% [markdown]
# ## Save ข้อมูลที่ preparation เรียบร้อยแล้ว จาก DataFrame ไปเป็น .csv

# %%
df.to_csv('data/clean_data.csv', header=True, index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Visualization

# %% [markdown]
# load ข้อมูล clean_data.csv เพื่อใช้ในการ Visualization

# %%
# -*- coding: utf-8 -*-
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
df = pd.read_csv('data/clean_data.csv')
df
# Out:
#               index_id                 index_description  region_id  \
# 0                    0                      รวมทุกรายการ          0
# 1                    0                      รวมทุกรายการ          0
# 2                    0                      รวมทุกรายการ          0
# 3                    0                      รวมทุกรายการ          0
# 4                    0                      รวมทุกรายการ          0
# ...                ...                               ...        ...
# 7695  9520000000000000  CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล          0
# 7696  9520000000000000  CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล          0
# 7697  9520000000000000  CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล          0
# 7698  9520000000000000  CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล          0
# 7699  9520000000000000  CPI ไม่รวมน้ำมัน 91 , 95 , ดีเซล          0
#
#                   region_name  base_year  year  month  price_index   mon  \
# 0     กรุงเทพมหานครและปริมณฑล       2015  2017      1       100.53  0.07
# 1     กรุงเทพมหานครและปริมณฑล       2015  2017      2       100.53  0.00
# 2     กรุงเทพมหานครและปริมณฑล       2015  2017      3       100.18 -0.35
# 3     กรุงเทพมหานครและปริมณฑล       2015  2017      4       100.34  0.16
# 4     กรุงเทพมหานครและปริมณฑล       2015  2017      5       100.48  0.14
# ...                       ...        ...   ...    ...          ...   ...
# 7695  กรุงเทพมหานครและปริมณฑล       2015  2020      4       100.43 -1.72
# 7696  กรุงเทพมหานครและปริมณฑล       2015  2020      5       100.29 -0.14
# 7697  กรุงเทพมหานครและปริมณฑล       2015  2020      6       101.70  1.41
# 7698  กรุงเทพมหานครและปริมณฑล       2015  2020      7       102.43  0.72
# 7699  กรุงเทพมหานครและปริมณฑล       2015  2020      8       102.67  0.23
#
#        yoy   aoa
# 0     1.18  1.18
# 1     1.00  1.09
# 2     0.49  0.88
# 3     0.18  0.71
# 4    -0.04  0.56
# ...    ...   ...
# 7695 -2.14 -0.14
# 7696 -2.78 -0.66
# 7697 -1.31 -0.78
# 7698 -0.64 -0.75
# 7699 -0.21 -0.69
#
# [7700 rows x 11 columns]

# %% [markdown]
# ## แสดงดัชนีราคาตั้งแต่ปีค.ศ. 2017-2020
# #### Line plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
CPI_Index = pd.read_csv("data/รหัสหมวดดัชนี CPI_INDEX 31-8-2020.csv", dtype={'รหัสดัชนี': np.int64})
CPI_index_id = CPI_Index['รหัสดัชนี']
CPI_index_id_list = CPI_index_id.tolist()
# CPI_index_id_list

# %%
index_ = df[df.index_id == 0]
month = index_['month'].tolist()
year = index_['year'].tolist()
price_index = index_['price_index'].tolist()
month_year = []
for i in range(len(month)):
    month_year.append(str(month[i]) + '/' + str(year[i])[2:] )

plt.figure(figsize=(25, 3))
plt.title(u'รวมทุกรายการ' ,fontname='Tahoma',fontsize='20')
plt.xlabel(u'เดือน/ปี',fontname='Tahoma',fontsize='18')
plt.ylabel(u'ดัชนีราคา',fontname='Tahoma',fontsize='18')
plt.plot(month_year, price_index, '-bo');

# %% [markdown]
# จากกราฟเส้น **รวมทุกรายการ** จะเห็นได้ว่าเพราะข่าวไวรัสโควิด-19 ในช่วงต้นปี2020 จะเห็นได้ชัดเจนว่าคนเริ่มไม่กล้าใช้เงิน ทำให้ต้องปรับราคาสินค้าลง (ลดราคาลงเพื่อให้ของขายออก) และเมื่อมีประกาศพรก.ฉุกเฉินจากรัฐบาลเมื่อวันที่ 25/03/2020 (https://www.bangkokbiznews.com/news/detail/872653) จะเห็นได้ว่าราคาสินค้าต่างๆลดลงอย่างชัดเจน ซึ่งเมื่อข่าวไวรัสโควิด-19 เริ่มดีขึ้นราคาสินค้าต่างๆก็เริ่มกลับขึ้นมา

# %%
#มีทั้งหมด 189 หมวด (1-189) ไม่นับหมวดรวมทุกรายการ ถ้าใส่เลขเยอะจะใช้เวลารันนาน
show = 9

for i in CPI_index_id_list[1:show]:
    index_ = df[df.index_id == i]
    month = index_['month'].tolist()
    year = index_['year'].tolist()
    price_index = index_['price_index'].tolist()
    month_year = []
    for i in range(len(month)):
        month_year.append(str(month[i]) + '/' + str(year[i])[2:] )

    if len(index_['index_description'].tolist()) > 0:
        plt.figure(figsize=(25, 3))
        plt.title(u''+index_['index_description'].tolist()[0] ,fontname='Tahoma',fontsize='20')
        plt.xlabel(u'เดือน/ปี',fontname='Tahoma',fontsize='18')
        plt.ylabel(u'ดัชนีราคา',fontname='Tahoma',fontsize='18')
        plt.plot(month_year, price_index, '-bo');
    else:
        continue

# %% [markdown]
# ## หมวดที่ราคาลดลง/เพิ่มขึ้น จากปีก่อนมากที่สุด 10 อันดับแรก
# #### Bar plot

# %%
lastFiveYOY = df[(df.year == 2020) & (df.month == 8)].sort_values(by=['yoy']).head(10)[::-1]
#หมวดที่ราคาลดลงจากปีก่อนมากที่สุด 10 อันดับแรก

tailFiveYOY = df[(df.year == 2020) & (df.month == 8)].sort_values(by=['yoy']).tail(10)
#หมวดที่ราคาเพิ่มขึ้นจากปีก่อนมากที่สุด 10 อันดับแรก

# %%
plt.rc('font', **{'family' : 'Tahoma',
                 'size' : '14'})

plt.figure(figsize=(10, 7))
plt.subplots_adjust(top = 10, bottom=9)

plt.subplot(2,1,1)
plt.title(u'ราคาในเดือนเดียวกันเมื่อเทียบกับปีก่อนหน้า' ,fontname='Tahoma',fontsize='18')
plt.barh(lastFiveYOY['index_description'], lastFiveYOY['yoy'])
plt.xlabel(u'ราคาที่ลดลงจากปีก่อน (บาท)');

plt.subplot(2,1,2)
plt.barh(tailFiveYOY['index_description'], tailFiveYOY['yoy'])
plt.xlabel(u'ราคาที่เพิ่มขึ้นจากปีก่อน (บาท)');

# %%
relatedCategories = lastFiveYOY['index_description'].tolist()
for i in relatedCategories:
    print(i)
# Out:
# การศึกษาระดับมัธยมศึกษา ด้านเทคนิคและอาชีวะ
# กลุ่มอาหารสดและพลังงาน
# หมวดพาหนะ การขนส่ง และการสื่อสาร
# ยานพาหนะและน้ำมันเชื้อเพลิง
# ผลไม้สดแปรรูปและอื่นๆ
# ผลไม้สด
# พลังงาน
# เชื้อเพลิงในบ้าน
# น้ำมัน 91 , 95 , ดีเซล
# น้ำมันเชื้อเพลิง

# %%
def createRelatedCategories(index):
    return df[df.index_description == relatedCategories[index]]['price_index'].tolist()

# %%
plt.rc('font', **{'family' : 'Tahoma',
                 'size' : '14'})

relatedCategories = lastFiveYOY['index_description'].tolist()

index_ = df[df.index_id == 0]
month = index_['month'].tolist()
year = index_['year'].tolist()
# price_index = index_['price_index'].tolist()
month_year = []
for i in range(len(month)):
    month_year.append(str(month[i]) + '/' + str(year[i])[2:] )

plt.figure(figsize=(30, 5))

for i in range(len(relatedCategories)):
    relatedCategories_i = createRelatedCategories(i)
    plt.plot(month_year, relatedCategories_i, label=relatedCategories[i])
    
plt.title(u'หมวดที่ราคาลดลงจากปีก่อนมากที่สุด 10 อันดับแรก', y=-0.3, fontsize='26')
plt.xlabel(u'เดือน/ปี')
plt.ylabel(u'ดัชนีราคา')


plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=4, mode="expand", borderaxespad=0., fontsize='20')

plt.show();

# %%
# plt.rc('font', **{'family' : 'Tahoma',
#                  'size' : '18'})

relatedCategories = lastFiveYOY['index_description'].tolist()


index_ = df[(df.index_id == 0) & (df.year != 2017)]
month = index_['month'].tolist()
year = index_['year'].tolist()
# price_index = index_['price_index'].tolist()
month_year = []
for i in range(len(month)):
    month_year.append(str(month[i]) + '/' + str(year[i])[2:] )

plt.figure(figsize=(30, 5))

for i in range(len(relatedCategories)):
    relatedCategories_i = createRelatedCategories(i)
    plt.plot(month_year, relatedCategories_i[12:], label=relatedCategories[i])
#     print(len(month_year), len(relatedCategories_i[13:]))
plt.title(u'หมวดที่ราคาลดลงจากปีก่อนมากที่สุด 10 อันดับแรก', y=-0.3, fontsize='26')
plt.xlabel(u'เดือน/ปี')
plt.ylabel(u'ดัชนีราคา')


plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=4, mode="expand", borderaxespad=0., fontsize='20')

plt.show()
# print(month_year)

# %% [markdown]
# ## หมวดที่ราคาลดลง/เพิ่มขึ้น จากเเดือนก่อนมากที่สุด 10 อันดับแรก
# #### Bar plot

# %%
lastFiveMON = df[(df.year == 2020) & (df.month == 8)].sort_values(by=['mon']).head(10)[::-1]
#หมวดที่ราคาลดลงจากปีก่อนมากที่สุด 10 อันดับแรก

tailFiveMON = df[(df.year == 2020) & (df.month == 8)].sort_values(by=['mon']).tail(10)
#หมวดที่ราคาเพิ่มขึ้นจากปีก่อนมากที่สุด 10 อันดับแรก

# %%
plt.rc('font', **{'family' : 'Tahoma',
                 'size' : '14'})

plt.figure(figsize=(10, 7))
plt.subplots_adjust(top = 10, bottom=9)

plt.subplot(2,1,1)
plt.title(u'ราคาในเดือนเดียวกันเมื่อเทียบกับเดือนก่อนหน้า' ,fontname='Tahoma',fontsize='18')
plt.barh(lastFiveMON['index_description'], lastFiveMON['mon'])
plt.xlabel(u'ราคาที่ลดลงจากเดือนก่อน (บาท)');

plt.subplot(2,1,2)
plt.barh(tailFiveMON['index_description'], tailFiveMON['mon'])
plt.xlabel(u'ราคาที่เพิ่มขึ้นจากเดือนก่อน (บาท)');

# %% [markdown]
# ## หาสัดส่วนราคาสินค้าลด เพิ่ม เท่าเดิม
# #### Pie chart

# %%
percentDecrease = round(len(df[df.yoy < 0])/len(df)*100, 2)
percentSame = round(len(df[df.yoy == 0])/len(df)*100, 2)
percentIncrease = round(len(df[df.yoy > 0])/len(df)*100, 2)

print('ราคาลดลง:\t',percentDecrease, '\nราคาเท่าเดิม:\t',percentSame, '\nราคาเพิ่มขึ้น:\t', percentIncrease)
print('รวมทั้งหมด:\t', percentDecrease + percentSame + percentIncrease)
# Out:
# ราคาลดลง:	 26.09
# ราคาเท่าเดิม:	 24.91
# ราคาเพิ่มขึ้น:	 49.0
# รวมทั้งหมด:	 100.0

# %%
values = [percentDecrease, percentSame, percentIncrease]
lables = ['ราคาลดลง', 'ราคาเท่าเดิม', 'ราคาเพิ่มขึ้น']
explode = (0, 0, 0.1)
plt.title(u'สัดส่วนอัตราการเปลี่ยนแปลงเทียบกับเดือนเดียวกันปีก่อนหน้า' ,fontname='Tahoma',fontsize='18')
plt.pie(values, explode=explode, labels=lables, shadow=True, autopct='%1.1f%%', startangle=90);
